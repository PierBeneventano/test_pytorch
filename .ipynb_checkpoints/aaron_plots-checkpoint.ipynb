# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import re
import os
import pickle
import glob
import os
import pdb
import matplotlib as mpl

import torch

# %%
f = torch.load('a.pt', map_location ='cpu')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-08675af6e257> in <module>
# ----> 1 f = torch.load('a.pt', map_location ='cpu')
#
# ~\anaconda3\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     525
#     526     Args:
# --> 527         f: a file-like object (has to implement :meth:`read`, :meth:`readline`, :meth:`tell`, and :meth:`seek`),
#     528             or a string or os.PathLike object containing a file name
#     529         map_location: a function, :class:`torch.device`, string or a dict specifying how to remap storage
#
# ~\anaconda3\lib\site-packages\torch\serialization.py in __init__(self, name_or_buffer)
#     222
#     223 class _open_buffer_writer(_opener):
# --> 224     def __exit__(self, *args):
#     225         self.file_like.flush()
#     226
#
# ...

# %%
sgdtrainmom=np.load("SGDMCIFAR10_train.npy")
mixtrainmom=np.load("trainbestmixSGD01505.npy")
gdtrainmom=np.load("GDMCIFAR10_train.npy")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-3618b74e6608> in <module>
# ----> 1 sgdtrainmom=np.load("SGDMCIFAR10_train.npy")
#       2 mixtrainmom=np.load("trainbestmixSGD01505.npy")
#       3 gdtrainmom=np.load("GDMCIFAR10_train.npy")
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: 'SGDMCIFAR10_train.npy'

# %%
import pickle
import glob
import os
import pdb

import itertools
import random
from types import SimpleNamespace
from random import shuffle
import numpy as np
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from scipy.special import loggamma, factorial2

# %%
toplot = {
    'SGD+M': {'color': '#659BC9'},
    'GD+M': { 'color': "#7BB661"},
    'GD+M+noise': { 'color': "#7BB661"},

}
 
results = {}

# %%
toplot
# Out:
# {'SGD+M': {'color': '#659BC9'},
#  'GD+M': {'color': '#7BB661'},
#  'GD+M+noise': {'color': '#7BB661'}}

# %%
 for label, fields in toplot.items():
        if label == 'SGD+M':
           # accuracy_adam = mean_ad
            results[label]=sgdtrainmom
        if label == 'GD+M':
          #  accuracy_da = mean
            results[label]=gdtrainmom
        if label == 'GD+M+noise':
          #  accuracy_da = mean
            results[label]=mixtrainmom

# %%
for res1 in results.items():
    print("ok")
# Out:
# ok
# ok
# ok

# %%
################################

mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['axes.titlesize'] = 6
mpl.rcParams['axes.labelsize'] = 6
mpl.rcParams['font.size'] = 6
mpl.rcParams['legend.fontsize'] = 6
linewidth = '0.4'
mpl.rcParams['lines.linewidth'] = 0.8
mpl.rcParams['axes.linewidth'] = linewidth
mpl.rcParams['xtick.major.width'] = linewidth
mpl.rcParams['ytick.major.width'] = linewidth

fig = plt.figure(figsize=(2.3, 1.88))

ax = fig.add_subplot(1, 1, 1)
for res1 in results.items():
    lbl = res1[0]
    accuracy = res1[1]#[0]
    xp = np.array(range(len(accuracy)))
    fields = toplot[lbl]
    label = f"{lbl} ({accuracy[-1]:2.2f})"
    ax.plot(xp, accuracy, alpha=0.5, label=label)

ax.set_xlabel('Number of epochs ')
ax.set_ylabel('Training loss')
ax.set_title("CIFAR-10")
ax.legend(loc='upper right')

plt.tight_layout()
fname = "cifar10trainvgg.pdf"
plt.savefig(fname)
print(f"Saved {fname}")
# Out:
# Saved cifar10trainvgg.pdf

# %%
sgdtestmom=np.load("SGDMCIFAR10_test.npy")
mixtestmom=np.load("testbestmixSGD01505.npy")
gdtestmom=np.load("GDMCIFAR10_test.npy")

# %%
import pickle
import glob
import os
import pdb

import itertools
import random
from types import SimpleNamespace
from random import shuffle
import numpy as np
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from scipy.special import loggamma, factorial2

# %%
toplot = {
    'SGD+M': {'color': '#659BC9'},
    'GD+M': { 'color': "#7BB661"},
    'GD+M+noise': { 'color': "#7BB661"},

}
 
results = {}

# %%
toplot
# Out:
# {'SGD+M': {'color': '#659BC9'},
#  'GD+M': {'color': '#7BB661'},
#  'GD+M+noise': {'color': '#7BB661'}}

# %%
 for label, fields in toplot.items():
        if label == 'SGD+M':
           # accuracy_adam = mean_ad
            results[label]=sgdtestmom
        if label == 'GD+M':
          #  accuracy_da = mean
            results[label]=gdtestmom
        if label == 'GD+M+noise':
          #  accuracy_da = mean
            results[label]=mixtestmom

# %%
for res1 in results.items():
    print("ok")
# Out:
# ok
# ok
# ok

# %%
################################

mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['axes.titlesize'] = 6
mpl.rcParams['axes.labelsize'] = 6
mpl.rcParams['font.size'] = 6
mpl.rcParams['legend.fontsize'] = 6
linewidth = '0.4'
mpl.rcParams['lines.linewidth'] = 0.8
mpl.rcParams['axes.linewidth'] = linewidth
mpl.rcParams['xtick.major.width'] = linewidth
mpl.rcParams['ytick.major.width'] = linewidth

fig = plt.figure(figsize=(2.3, 1.88))

ax = fig.add_subplot(1, 1, 1)
for res1 in results.items():
    lbl = res1[0]
    accuracy = res1[1]#[0]
    xp = np.array(range(len(accuracy)))
    fields = toplot[lbl]
    label = f"{lbl} ({accuracy[-1]:2.2f})"
    ax.plot(xp, accuracy, alpha=0.5, label=label)

ax.set_xlabel('Number of epochs ')
ax.set_ylabel('Accuracy')
ax.set_title("CIFAR-10")
ax.legend(loc='lower right')

plt.tight_layout()
fname = "cifar10testvgg.pdf"
plt.savefig(fname)
print(f"Saved {fname}")
# Out:
# Saved cifar10testvgg.pdf

# %%
testmom=np.load("testCIFAR100mom_VGG.npy")
 
test1=np.load("testCIFAR100LR1_VGG.npy")

# %%
import pickle
import glob
import os
import pdb

import itertools
import random
from types import SimpleNamespace
from random import shuffle
import numpy as np
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from scipy.special import loggamma, factorial2

# %%
toplot = {
    'SGD+M': {'color': '#659BC9'},
    'SGDLR1': { 'color': "#7BB661"},
#    'SGDmom20': { 'color': "#7BB661"},
#    'SGDmom50': { 'color': "#556B2F"},

}
 
results = {}

# %%
toplot
# Out:
# {'SGD+M': {'color': '#659BC9'}, 'SGDLR1': {'color': '#7BB661'}}

# %%
 for label, fields in toplot.items():
        if label == 'SGD+M':
           # accuracy_adam = mean_ad
            results[label]=testmom
        if label == 'SGD':
          #  accuracy_da = mean
            results[label]=testnomom
        if label == 'SGD+M50':
          #  accuracy_da = mean
            results[label]=testmom50
        if label == 'SGDLR1':
          #  accuracy_da = mean
            results[label]=test1

# %%
for res1 in results.items():
    print("ok")
# Out:
# ok
# ok

# %%
################################

mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['axes.titlesize'] = 6
mpl.rcParams['axes.labelsize'] = 6
mpl.rcParams['font.size'] = 6
mpl.rcParams['legend.fontsize'] = 6
linewidth = '0.4'
mpl.rcParams['lines.linewidth'] = 0.8
mpl.rcParams['axes.linewidth'] = linewidth
mpl.rcParams['xtick.major.width'] = linewidth
mpl.rcParams['ytick.major.width'] = linewidth

fig = plt.figure(figsize=(2.3, 1.88))

ax = fig.add_subplot(1, 1, 1)
for res1 in results.items():
    lbl = res1[0]
    accuracy = res1[1]#[0]
    xp = np.array(range(len(accuracy)))
    fields = toplot[lbl]
    label = f"{lbl} ({accuracy[-1]:2.2f})"
    ax.plot(xp, accuracy, alpha=0.5, label=label)

ax.set_xlabel('Number of epochs ')
ax.set_ylabel('Accuracy')
ax.set_title("CIFAR-100")
ax.legend(loc='lower right')

plt.tight_layout()
fname = "cifar100vgg.pdf"
plt.savefig(fname)
print(f"Saved {fname}")
# Out:
# Saved cifar100vgg.pdf

# %%
testmom=np.load("SGDmom100_align.npy")
#testmom50=np.load("SGDmom50_align.npy")

#testnomom=np.load("SGD_align.npy")
test1=np.load("SGDLR1100_align.npy")

# %%
toplot={}

# %%
toplot = {
    'SGD+M': {'color': '#659BC9'},
#    'SGD': { 'color': "#000000"},
 #   'SGD+M50': { 'color': "#ACE1AF"},
     'SGDLR1': { 'color': "##000000"},

    
#    'SGDmom20': { 'color': "#7BB661"},
#    'SGDmom50': { 'color': "#556B2F"},

}
results = {}

# %%
toplot
# Out:
# {'SGD+M': {'color': '#659BC9'}, 'SGDLR1': {'color': '##000000'}}

# %%
for label, fields in toplot.items():
        if label == 'SGD+M':
           # accuracy_adam = mean_ad
            results[label]=testmom
#        if label == 'SGD':
          #  accuracy_da = mean
#            results[label]=testnomom
#        if label == 'SGD+M50':
          #  accuracy_da = mean
#            results[label]=testmom50
        if label == 'SGDLR1':
          #  accuracy_da = mean
            results[label]=test1

# %%
num_param = results['SGD+M'].shape[1]

# %%
num_param
# Out:
# 62

# %%
################################

mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['axes.titlesize'] = 6
mpl.rcParams['axes.labelsize'] = 6
mpl.rcParams['font.size'] = 6
mpl.rcParams['legend.fontsize'] = 6
linewidth = '0.4'
mpl.rcParams['lines.linewidth'] = 0.8
mpl.rcParams['axes.linewidth'] = linewidth
mpl.rcParams['xtick.major.width'] = linewidth
mpl.rcParams['ytick.major.width'] = linewidth



for i in range(num_param):

    fig = plt.figure(figsize=(2.3, 1.88))

    ax = fig.add_subplot(1, 1, 1)
    
    for res1 in results.items():
        lbl = res1[0]
        accuracy = res1[1][:,i]#[0]
        xp = np.array(range(len(accuracy)))
        fields = toplot[lbl]
        label = f"{lbl} ({accuracy[-1]:2.2f})"
        ax.plot(xp,  accuracy , alpha=0.5, label=label)
        
        

    ax.set_xlabel('Number of epochs ')
    ax.set_ylabel(r'$\nabla f(x_t)^{\top}(x_t-x_{t-1})$')
    ax.set_title("Alignment in CIFAR-100 for param "+str(i+1))
    ax.legend(loc='lower right')

    plt.tight_layout()
    fname="plots_align/alignement100param{}.pdf".format(i+1) 
    plt.savefig(fname)
    print(f"Saved {fname}")
# Out:
# Saved plots_align/alignement100param1.pdf
# Saved plots_align/alignement100param2.pdf
# Saved plots_align/alignement100param3.pdf
# Saved plots_align/alignement100param4.pdf
# Saved plots_align/alignement100param5.pdf
# Saved plots_align/alignement100param6.pdf
# Saved plots_align/alignement100param7.pdf
# Saved plots_align/alignement100param8.pdf
# Saved plots_align/alignement100param9.pdf
# Saved plots_align/alignement100param10.pdf
# Saved plots_align/alignement100param11.pdf
# Saved plots_align/alignement100param12.pdf
# Saved plots_align/alignement100param13.pdf
# Saved plots_align/alignement100param14.pdf
# Saved plots_align/alignement100param15.pdf
# Saved plots_align/alignement100param16.pdf
# Saved plots_align/alignement100param17.pdf
# Saved plots_align/alignement100param18.pdf
# Saved plots_align/alignement100param19.pdf
# Saved plots_align/alignement100param20.pdf
# ...

# %%
testmom=np.load("gradnormCIFAR100mom_VGG.npy")
#testmom50=np.load("SGDmom50_align.npy")

#testnomom=np.load("SGD_align.npy")
test1=np.load("gradnormCIFAR100LR1_VGG.npy")

# %%
toplot = {
    'SGD+M': {'color': '#659BC9'},
#    'SGD': { 'color': "#000000"},
 #   'SGD+M50': { 'color': "#ACE1AF"},
     'SGDLR1': { 'color': "##000000"},

    
#    'SGDmom20': { 'color': "#7BB661"},
#    'SGDmom50': { 'color': "#556B2F"},

}
results = {}

# %%
for label, fields in toplot.items():
        if label == 'SGD+M':
           # accuracy_adam = mean_ad
            results[label]=testmom
#        if label == 'SGD':
          #  accuracy_da = mean
#            results[label]=testnomom
#        if label == 'SGD+M50':
          #  accuracy_da = mean
#            results[label]=testmom50
        if label == 'SGDLR1':
          #  accuracy_da = mean
            results[label]=test1

# %%
for res1 in results.items():
        print("ok")
# Out:
# ok
# ok

# %%
num_param = results['SGD+M'].shape[1]

# %%
num_param
# Out:
# 58

# %%
################################

mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['axes.titlesize'] = 6
mpl.rcParams['axes.labelsize'] = 6
mpl.rcParams['font.size'] = 6
mpl.rcParams['legend.fontsize'] = 6
linewidth = '0.4'
mpl.rcParams['lines.linewidth'] = 0.8
mpl.rcParams['axes.linewidth'] = linewidth
mpl.rcParams['xtick.major.width'] = linewidth
mpl.rcParams['ytick.major.width'] = linewidth



for i in range(num_param):

    fig = plt.figure(figsize=(2.3, 1.88))

    ax = fig.add_subplot(1, 1, 1)
    
    for res1 in results.items():
        lbl = res1[0]
        accuracy = res1[1][:,i]#[0]
        xp = np.array(range(len(accuracy)))
        fields = toplot[lbl]
        label = f"{lbl} ({accuracy[-1]:2.2f})"
        ax.plot(xp,  accuracy , alpha=0.5, label=label)
        
        

    ax.set_xlabel('Number of epochs ')
    ax.set_ylabel(r'$|| \nabla f(x_t) ||^2$')
    ax.set_title("Gradient norm in CIFAR-100 for param "+str(i+1))
    ax.legend(loc='upper left')

    plt.tight_layout()
    fname="plots_grad/gradnorm100param{}.pdf".format(i+1) 
    plt.savefig(fname)
    print(f"Saved {fname}")
# Out:
# Saved plots_grad/gradnorm100param1.pdf
# Saved plots_grad/gradnorm100param2.pdf
# Saved plots_grad/gradnorm100param3.pdf
# Saved plots_grad/gradnorm100param4.pdf
# Saved plots_grad/gradnorm100param5.pdf
# Saved plots_grad/gradnorm100param6.pdf
# Saved plots_grad/gradnorm100param7.pdf
# Saved plots_grad/gradnorm100param8.pdf
# Saved plots_grad/gradnorm100param9.pdf
# Saved plots_grad/gradnorm100param10.pdf
# Saved plots_grad/gradnorm100param11.pdf
# Saved plots_grad/gradnorm100param12.pdf
# Saved plots_grad/gradnorm100param13.pdf
# Saved plots_grad/gradnorm100param14.pdf
# Saved plots_grad/gradnorm100param15.pdf
# Saved plots_grad/gradnorm100param16.pdf
# Saved plots_grad/gradnorm100param17.pdf
# Saved plots_grad/gradnorm100param18.pdf
# Saved plots_grad/gradnorm100param19.pdf
# Saved plots_grad/gradnorm100param20.pdf
# ...

# %%
T=np.arange(0,30)

# %%
testmom=np.load("aligngrad10_cifar100mom.npy")
#testmom50=np.load("SGDmom50_align.npy")

#testnomom=np.load("SGD_align.npy")
test1=np.load("aligngrad10_cifar100LR1.npy")

# %%
toplot={}

# %%
toplot = {
    'SGD+M': {'color': '#659BC9'},
#    'SGD': { 'color': "#000000"},
 #   'SGD+M50': { 'color': "#ACE1AF"},
     'SGDLR1': { 'color': "##000000"},

    
#    'SGDmom20': { 'color': "#7BB661"},
#    'SGDmom50': { 'color': "#556B2F"},

}
results = {}

# %%
toplot
# Out:
# {'SGD+M': {'color': '#659BC9'}, 'SGDLR1': {'color': '##000000'}}

# %%
for label, fields in toplot.items():
        if label == 'SGD+M':
           # accuracy_adam = mean_ad
            results[label]=testmom
#        if label == 'SGD':
          #  accuracy_da = mean
#            results[label]=testnomom
#        if label == 'SGD+M50':
          #  accuracy_da = mean
#            results[label]=testmom50
        if label == 'SGDLR1':
          #  accuracy_da = mean
            results[label]=test1

# %%
num_param = results['SGD+M'].shape[1]

# %%
num_param
# Out:
# 62

# %%
################################

mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['axes.titlesize'] = 6
mpl.rcParams['axes.labelsize'] = 6
mpl.rcParams['font.size'] = 6
mpl.rcParams['legend.fontsize'] = 6
linewidth = '0.4'
mpl.rcParams['lines.linewidth'] = 0.8
mpl.rcParams['axes.linewidth'] = linewidth
mpl.rcParams['xtick.major.width'] = linewidth
mpl.rcParams['ytick.major.width'] = linewidth



for i in range(num_param):

    fig = plt.figure(figsize=(2.3, 1.88))

    ax = fig.add_subplot(1, 1, 1)
    
    for res1 in results.items():
        lbl = res1[0]
        accuracy = res1[1][:,i]#[0]
        xp = np.array(range(len(accuracy)))
        fields = toplot[lbl]
        label = f"{lbl} ({accuracy[-1]:2.2f})"
        ax.plot(xp,  accuracy , alpha=0.5, label=label)
        
        

    ax.set_xlabel('Number of epochs ')
    ax.set_ylabel(r'$\frac{1}{T}\sum_{t=1}^T\nabla f(x_t)^{\top}\nabla f(x_{t-1}) $')
    ax.set_title("Alignment in CIFAR-100 for param "+str(i+1))
    ax.legend(loc='upper right')

    plt.tight_layout()
    fname="plots_yuanzalign/alignement100param{}.pdf".format(i+1) 
    plt.savefig(fname)
    print(f"Saved {fname}")
# Out:
# Saved plots_yuanzalign/alignement100param1.pdf
# Saved plots_yuanzalign/alignement100param2.pdf
# Saved plots_yuanzalign/alignement100param3.pdf
# Saved plots_yuanzalign/alignement100param4.pdf
# Saved plots_yuanzalign/alignement100param5.pdf
# Saved plots_yuanzalign/alignement100param6.pdf
# Saved plots_yuanzalign/alignement100param7.pdf
# Saved plots_yuanzalign/alignement100param8.pdf
# Saved plots_yuanzalign/alignement100param9.pdf
# Saved plots_yuanzalign/alignement100param10.pdf
# Saved plots_yuanzalign/alignement100param11.pdf
# Saved plots_yuanzalign/alignement100param12.pdf
# Saved plots_yuanzalign/alignement100param13.pdf
# Saved plots_yuanzalign/alignement100param14.pdf
# Saved plots_yuanzalign/alignement100param15.pdf
# Saved plots_yuanzalign/alignement100param16.pdf
# Saved plots_yuanzalign/alignement100param17.pdf
# Saved plots_yuanzalign/alignement100param18.pdf
# Saved plots_yuanzalign/alignement100param19.pdf
# Saved plots_yuanzalign/alignement100param20.pdf
# ...

# %%
testmom=np.load("ratiomomgVGG_cifar100mom.npy")
#testmom50=np.load("SGDmom50_align.npy")

#testnomom=np.load("SGD_align.npy")
test1=np.load("ratiomomgVGG_cifar100LR1.npy")

# %%
toplot={}

# %%
toplot = {
    'SGD+M': {'color': '#659BC9'},
#    'SGD': { 'color': "#000000"},
 #   'SGD+M50': { 'color': "#ACE1AF"},
     'SGDLR1': { 'color': "##000000"},

    
#    'SGDmom20': { 'color': "#7BB661"},
#    'SGDmom50': { 'color': "#556B2F"},

}
results = {}

# %%
toplot
# Out:
# {'SGD+M': {'color': '#659BC9'}, 'SGDLR1': {'color': '##000000'}}

# %%
for label, fields in toplot.items():
        if label == 'SGD+M':
           # accuracy_adam = mean_ad
            results[label]=testmom
#        if label == 'SGD':
          #  accuracy_da = mean
#            results[label]=testnomom
#        if label == 'SGD+M50':
          #  accuracy_da = mean
#            results[label]=testmom50
        if label == 'SGDLR1':
          #  accuracy_da = mean
            results[label]=test1

# %%
num_param = results['SGD+M'].shape[1]

# %%
num_param
# Out:
# 58

# %%
################################

mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['axes.titlesize'] = 6
mpl.rcParams['axes.labelsize'] = 6
mpl.rcParams['font.size'] = 6
mpl.rcParams['legend.fontsize'] = 6
linewidth = '0.4'
mpl.rcParams['lines.linewidth'] = 0.8
mpl.rcParams['axes.linewidth'] = linewidth
mpl.rcParams['xtick.major.width'] = linewidth
mpl.rcParams['ytick.major.width'] = linewidth



for i in range(num_param):

    fig = plt.figure(figsize=(2.3, 1.88))

    ax = fig.add_subplot(1, 1, 1)
    
    for res1 in results.items():
        lbl = res1[0]
        accuracy = res1[1][:,i]#[0]
        xp = np.array(range(len(accuracy)))
        fields = toplot[lbl]
        label = f"{lbl} ({accuracy[-1]:2.2f})"
        ax.plot(xp,  accuracy , alpha=0.5, label=label)
        
        

    ax.set_xlabel('Number of epochs ')
    ax.set_ylabel(r'$||x_t-x_{t-1}||_2/||\nabla f(x_t)||_2$')
    ax.set_title("Momentum/grad in CIFAR-100 for param "+str(i+1))
    ax.legend(loc='upper right')

    plt.tight_layout()
    fname="plots_ratio/ratio100param{}.pdf".format(i+1) 
    plt.savefig(fname)
    print(f"Saved {fname}")
# Out:
# Saved plots_ratio/ratio100param1.pdf
# Saved plots_ratio/ratio100param2.pdf
# Saved plots_ratio/ratio100param3.pdf
# Saved plots_ratio/ratio100param4.pdf
# Saved plots_ratio/ratio100param5.pdf
# Saved plots_ratio/ratio100param6.pdf
# Saved plots_ratio/ratio100param7.pdf
# Saved plots_ratio/ratio100param8.pdf
# Saved plots_ratio/ratio100param9.pdf
# Saved plots_ratio/ratio100param10.pdf
# Saved plots_ratio/ratio100param11.pdf
# Saved plots_ratio/ratio100param12.pdf
# Saved plots_ratio/ratio100param13.pdf
# Saved plots_ratio/ratio100param14.pdf
# Saved plots_ratio/ratio100param15.pdf
# Saved plots_ratio/ratio100param16.pdf
# Saved plots_ratio/ratio100param17.pdf
# Saved plots_ratio/ratio100param18.pdf
# Saved plots_ratio/ratio100param19.pdf
# Saved plots_ratio/ratio100param20.pdf
# ...
